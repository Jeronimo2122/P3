# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Ruta del archivo con comillas
ruta_archivo = "DF_FINAL.csv"

# Leer el archivo CSV en un DataFrame
df = pd.read_csv(ruta_archivo)

# Mostrar las primeras filas del DataFrame
df
# Out:
#        cole_bilingue  cole_naturaleza_oficial  cole_sede_principal  \
# 0                  0                        1                    1
# 1                  0                        1                    1
# 2                  0                        1                    1
# 3                  0                        0                    1
# 4                  0                        1                    1
# ...              ...                      ...                  ...
# 73792              0                        1                    1
# 73793              0                        0                    1
# 73794              0                        1                    1
# 73795              0                        1                    0
# 73796              0                        1                    1
#
#        estu_privado_libertad  fami_personashogar  fami_tieneautomovil  \
# 0                          0                 4.0                    1
# ...

# %%
# Obtén las estadísticas descriptivas
estadisticas = df.describe()

# Muestra las primeras 10 columnas
print(df.describe().iloc[:, :10])
# Out:
#        cole_bilingue  cole_naturaleza_oficial  cole_sede_principal  \
# count   73797.000000             73797.000000         73797.000000
# mean        0.009919                 0.877908             0.971056
# std         0.099100                 0.327394             0.167651
# min         0.000000                 0.000000             0.000000
# 25%         0.000000                 1.000000             1.000000
# 50%         0.000000                 1.000000             1.000000
# 75%         0.000000                 1.000000             1.000000
# max         1.000000                 1.000000             1.000000
#
#        estu_privado_libertad  fami_personashogar  fami_tieneautomovil  \
# count                73797.0        73797.000000         73797.000000
# mean                     0.0            5.025719             0.128013
# std                      0.0            1.822730             0.334107
# min                      0.0            1.000000             0.000000
# ...

# %%
# Muestra las siguientes 10 columnas
print(df.describe().iloc[:, 10:20])
# Out:
#        punt_sociales_ciudadanas  punt_c_naturales  punt_lectura_critica  \
# count              73797.000000      73797.000000          73797.000000
# mean                  44.593913         45.904996             47.826511
# std                   10.549244          9.267460              9.630485
# min                    0.000000          0.000000              0.000000
# 25%                   37.000000         39.000000             41.000000
# 50%                   44.000000         45.000000             47.000000
# 75%                   52.000000         52.000000             54.000000
# max                  100.000000        100.000000            100.000000
#
#         punt_global  cole_area_ubicacion_URBANO  cole_calendario_A  \
# count  73797.000000                73797.000000       73797.000000
# mean     229.763893                    0.799748           0.996639
# std       43.437930                    0.400192           0.057873
# ...

# %%
# Muestra las siguientes columnas
print(df.describe().iloc[:, 20:40])
# Out:
#        cole_genero_MIXTO  cole_jornada_MAÑANA  cole_jornada_NOCHE  \
# count       73797.000000         73797.000000        73797.000000
# mean            0.972302             0.566229            0.091955
# std             0.164106             0.495598            0.288964
# min             0.000000             0.000000            0.000000
# 25%             1.000000             0.000000            0.000000
# 50%             1.000000             1.000000            0.000000
# 75%             1.000000             1.000000            0.000000
# max             1.000000             1.000000            1.000000
#
#        cole_jornada_SABATINA  cole_jornada_TARDE  cole_jornada_UNICA  \
# count           73797.000000        73797.000000        73797.000000
# mean                0.020516            0.174817            0.074773
# std                 0.141757            0.379813            0.263026
# min                 0.000000            0.000000            0.000000
# ...

# %% [markdown]
# Distribucion y comportamiento de la variable dependiente

# %%
plt.figure(figsize=(10, 8))
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm', fmt='.2f')
plt.title('Mapa de calor de la correlación')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['punt_global'], kde=True)
plt.title('Distribución de punt_global')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['punt_global'])
plt.title('Boxplot de punt_global')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df['punt_ingles'], y=df['punt_global'])
plt.title('Relación entre punt_ingles y punt_global')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df['punt_sociales_ciudadanas'], y=df['punt_global'])
plt.title('Relación entre punt_sociales_ciudadanas y punt_global')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df['punt_c_naturales'], y=df['punt_global'])
plt.title('Relación entre punt_c_naturales y punt_global')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df['punt_lectura_critica'], y=df['punt_global'])
plt.title('Relación entre punt_lectura_critica y punt_global')
plt.show()

# %% [markdown]
# *Variables Binarias*

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['cole_bilingue'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['cole_naturaleza_oficial'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['cole_sede_principal'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['fami_tieneautomovil'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['fami_tienecomputador'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['fami_tieneinternet'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['cole_area_ubicacion_URBANO'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['cole_calendario_A'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['cole_caracter_NO APLICA'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['cole_caracter_TÉCNICO'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['cole_caracter_TÉCNICO/ACADÉMICO'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['cole_genero_MASCULINO'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['cole_genero_MIXTO'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['cole_jornada_MAÑANA'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['cole_jornada_NOCHE'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['cole_jornada_SABATINA'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['cole_jornada_TARDE'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['cole_jornada_UNICA'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['estu_genero_masculino'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['pais_nacionalidad_reside'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['fami_estratovivienda_Estrato 2'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['fami_estratovivienda_Estrato 3'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['fami_estratovivienda_Estrato 4'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['fami_estratovivienda_Estrato 5'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['fami_estratovivienda_Estrato 6'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['fami_estratovivienda_Sin Estrato'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['desemp_ingles_A-'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['desemp_ingles_A1'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['desemp_ingles_A2'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['desemp_ingles_B+'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x=df['desemp_ingles_B1'], y=df['punt_global'])
plt.title('Distribución de punt_global por var_categorica')
plt.show()

# %%
# Diagrama de barras para la variable binaria 'cole_bilingue'
plt.figure(figsize=(8, 6))
sns.countplot(x='cole_bilingue', data=df)
plt.title('Distribución de Colegios Bilingües')
plt.xlabel('Colegios Bilingües (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Diagrama de barras para la variable binaria 'cole_bilingue'
plt.figure(figsize=(8, 6))
sns.countplot(x='cole_naturaleza_oficial', data=df)
plt.title('Distribución de Colegios Oficiales')
plt.xlabel('Colegios naturaleza oficial (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Diagrama de barras para la variable binaria 'cole_bilingue'
plt.figure(figsize=(8, 6))
sns.countplot(x='cole_sede_principal', data=df)
plt.title('Distribución de Colegios en sede principal')
plt.xlabel('Colegios sede principal (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Diagrama de barras para la variable binaria 'cole_bilingue'
plt.figure(figsize=(8, 6))
sns.countplot(x='fami_personashogar', data=df)
plt.title('Distribución de personas por hogar')
plt.xlabel('Personas por hogar (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Diagrama de barras para la variable binaria 'cole_bilingue'
plt.figure(figsize=(8, 6))
sns.countplot(x='fami_tieneautomovil', data=df)
plt.title('Distribución de personas que tienen automovil')
plt.xlabel('Tienen automovil (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Diagrama de barras para la variable binaria 'cole_bilingue'
plt.figure(figsize=(8, 6))
sns.countplot(x='fami_tienecomputador', data=df)
plt.title('Distribución de peronas que tienen computador')
plt.xlabel('Tienen computador (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Diagrama de barras para la variable binaria 'cole_bilingue'
plt.figure(figsize=(8, 6))
sns.countplot(x='fami_tieneinternet', data=df)
plt.title('Distribución de personas que tienen internet')
plt.xlabel('Tienen internet (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Diagrama de barras para la variable binaria 'cole_bilingue'
plt.figure(figsize=(8, 6))
sns.countplot(x='punt_ingles', data=df)
plt.title('Distribución de puntaje ingles')
plt.xlabel('Puntaje ingles')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Diagrama de barras para la variable binaria 'cole_bilingue'
plt.figure(figsize=(8, 6))
sns.countplot(x='punt_matematicas', data=df)
plt.title('Distribución de puntaje matematicas')
plt.xlabel('Puntaje matematicas')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Diagrama de barras para la variable binaria 'cole_bilingue'
plt.figure(figsize=(8, 6))
sns.countplot(x='punt_sociales_ciudadanas', data=df)
plt.title('Distribución de puntaje sociales ciudadanas')
plt.xlabel('Puntaje sociales ciudadanas')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Diagrama de barras para la variable binaria 'cole_bilingue'
plt.figure(figsize=(8, 6))
sns.countplot(x='punt_c_naturales', data=df)
plt.title('Distribución de puntaje ciencies naturales')
plt.xlabel('Puntaje ciencies naturales')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Diagrama de barras para la variable binaria 'cole_bilingue'
plt.figure(figsize=(8, 6))
sns.countplot(x='punt_lectura_critica', data=df)
plt.title('Distribución de puntaje lectura critica')
plt.xlabel('Puntaje lectura critica')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Diagrama de barras para la variable binaria 'cole_bilingue'
plt.figure(figsize=(8, 6))
sns.countplot(x='punt_global', data=df)
plt.title('Distribución de puntaje global')
plt.xlabel('Puntaje global')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Diagrama de barras para la variable binaria 'cole_bilingue'
plt.figure(figsize=(8, 6))
sns.countplot(x='cole_area_ubicacion_URBANO', data=df)
plt.title('Distribución de Colegios en area urbana')
plt.xlabel('el colegio esta en area urbana (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Diagrama de barras para la variable binaria 'cole_bilingue'
plt.figure(figsize=(8, 6))
sns.countplot(x='cole_calendario_A', data=df)
plt.title('Distribución de Colegios calendario A')
plt.xlabel('el colegio es calendario A (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Diagrama de barras para la variable binaria 'cole_bilingue'
plt.figure(figsize=(8, 6))
sns.countplot(x='cole_caracter_NO APLICA', data=df)
plt.title('Distribución de Colegios de caracter no aplica')
plt.xlabel('el colegio es es de caracter no aplica (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Diagrama de barras para la variable binaria 'cole_bilingue'
plt.figure(figsize=(8, 6))
sns.countplot(x='cole_caracter_TÉCNICO', data=df)
plt.title('Distribución de Colegios de caracter técnico')
plt.xlabel('el colegio es es de caracter técnico (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Diagrama de barras para la variable binaria 'cole_bilingue'
plt.figure(figsize=(8, 6))
sns.countplot(x='cole_caracter_TÉCNICO/ACADÉMICO', data=df)
plt.title('Distribución de Colegios de caracter técnico/academico')
plt.xlabel('el colegio es es de caracter técnico/académico (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Diagrama de barras para la variable binaria 'cole_bilingue'
plt.figure(figsize=(8, 6))
sns.countplot(x='cole_genero_MASCULINO', data=df)
plt.title('Distribución de Colegios masculinos')
plt.xlabel('el colegio es masculino (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Diagrama de barras para la variable binaria 'cole_bilingue'
plt.figure(figsize=(8, 6))
sns.countplot(x='cole_genero_MIXTO', data=df)
plt.title('Distribución de Colegios mixtos')
plt.xlabel('el colegio es mixto (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Diagrama de barras para la variable binaria 'cole_bilingue'
plt.figure(figsize=(8, 6))
sns.countplot(x='cole_jornada_MAÑANA', data=df)
plt.title('Distribución de jornada de la mañana')
plt.xlabel('el colegio es de jornada de mañana (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Diagrama de barras para la variable binaria 'cole_bilingue'
plt.figure(figsize=(8, 6))
sns.countplot(x='cole_jornada_NOCHE', data=df)
plt.title('Distribución de jornada de la noche')
plt.xlabel('el colegio es de jornada de noche (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='cole_jornada_SABATINA', data=df)
plt.title('Distribución de jornada sabatina')
plt.xlabel('el colegio es de jornada sabatina (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='cole_jornada_TARDE', data=df)
plt.title('Distribución de jornada en la tarde')
plt.xlabel('el colegio es de jornada de la tarde (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='cole_jornada_UNICA', data=df)
plt.title('Distribución de jornada unica')
plt.xlabel('el colegio es de jornada unica (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='estu_genero_masculino', data=df)
plt.title('Distribución para estudiantes de genero masculino')
plt.xlabel('el estudiante es de genero masculino (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='pais_nacionalidad_reside', data=df)
plt.title('Distribución para estudiantes que viven en el pais donde nacieron')
plt.xlabel('el estudiante vive en el pais donde nació (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='fami_estratovivienda_Estrato 2', data=df)
plt.title('Distribución para estudiantes que viven en estrato 2')
plt.xlabel('el estudiante vive en estrato 2 (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='fami_estratovivienda_Estrato 3', data=df)
plt.title('Distribución para estudiantes que viven en estrato 3')
plt.xlabel('el estudiante vive en estrato 3 (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='fami_estratovivienda_Estrato 4', data=df)
plt.title('Distribución para estudiantes que viven en estrato 4')
plt.xlabel('el estudiante vive en estrato 4 (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='fami_estratovivienda_Estrato 5', data=df)
plt.title('Distribución para estudiantes que viven en estrato 5')
plt.xlabel('el estudiante vive en estrato 5 (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='fami_estratovivienda_Estrato 6', data=df)
plt.title('Distribución para estudiantes que viven en estrato 6')
plt.xlabel('el estudiante vive en estrato 6 (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='fami_estratovivienda_Sin Estrato', data=df)
plt.title('Distribución para estudiantes que viven en un lugar sin estrato')
plt.xlabel('el estudiante vive en un lugar sin estrato (0 = No, 1 = Sí)')
plt.ylabel('Frecuencia')
plt.show()
