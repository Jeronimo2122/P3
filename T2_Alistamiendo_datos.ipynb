# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Ruta del archivo con comillas
ruta_archivo = "archivo_limpio_sin_columnas.csv"

# Leer el archivo CSV en un DataFrame
df = pd.read_csv(ruta_archivo)

# Mostrar las primeras filas del DataFrame
df
# Out:
#       cole_area_ubicacion cole_bilingue cole_calendario      cole_caracter  \
# 0                  URBANO             N               A            TÉCNICO
# 1                   RURAL             N               A          ACADÉMICO
# 2                  URBANO             N               A            TÉCNICO
# 3                  URBANO             N               A          ACADÉMICO
# 4                  URBANO             N               A  TÉCNICO/ACADÉMICO
# ...                   ...           ...             ...                ...
# 73792              URBANO             N               A  TÉCNICO/ACADÉMICO
# 73793              URBANO             N               A          ACADÉMICO
# 73794              URBANO             N               A          ACADÉMICO
# 73795              URBANO             N               A  TÉCNICO/ACADÉMICO
# 73796              URBANO             N               A          ACADÉMICO
#
# ...

# %% [markdown]
# variable cole_area_ubicacion

# %%
df['cole_area_ubicacion'].unique()
# Out:
# array(['URBANO', 'RURAL'], dtype=object)

# %%
# Convertir la variable 'cole_area_ubicacion' en variables dummy
df= pd.get_dummies(df, columns=['cole_area_ubicacion'], drop_first=True)


# Convertir la columna de valores True/False a 0 y 1
df['cole_area_ubicacion_URBANO'] = df['cole_area_ubicacion_URBANO'].astype(int)

# Mostrar las primeras filas del DataFrame actualizado
df
# Out:
#       cole_bilingue cole_calendario      cole_caracter cole_genero  \
# 0                 N               A            TÉCNICO       MIXTO
# 1                 N               A          ACADÉMICO       MIXTO
# 2                 N               A            TÉCNICO       MIXTO
# 3                 N               A          ACADÉMICO   MASCULINO
# 4                 N               A  TÉCNICO/ACADÉMICO       MIXTO
# ...             ...             ...                ...         ...
# 73792             N               A  TÉCNICO/ACADÉMICO       MIXTO
# 73793             N               A          ACADÉMICO       MIXTO
# 73794             N               A          ACADÉMICO       MIXTO
# 73795             N               A  TÉCNICO/ACADÉMICO       MIXTO
# 73796             N               A          ACADÉMICO       MIXTO
#
#       cole_jornada cole_mcpio_ubicacion cole_naturaleza cole_sede_principal  \
# 0           MAÑANA          SANTA MARTA         OFICIAL                   S
# ...

# %% [markdown]
# variable cole_bilingue

# %%
df['cole_bilingue'].unique()
# Out:
# array(['N', 'S'], dtype=object)

# %%
# Convertir la columna 'cole_bilingue' en una variable binaria
df['cole_bilingue'] = df['cole_bilingue'].apply(lambda x: 1 if x == 'S' else 0)

# Mostrar las primeras filas del DataFrame actualizado
df
# Out:
#        cole_bilingue cole_calendario      cole_caracter cole_genero  \
# 0                  0               A            TÉCNICO       MIXTO
# 1                  0               A          ACADÉMICO       MIXTO
# 2                  0               A            TÉCNICO       MIXTO
# 3                  0               A          ACADÉMICO   MASCULINO
# 4                  0               A  TÉCNICO/ACADÉMICO       MIXTO
# ...              ...             ...                ...         ...
# 73792              0               A  TÉCNICO/ACADÉMICO       MIXTO
# 73793              0               A          ACADÉMICO       MIXTO
# 73794              0               A          ACADÉMICO       MIXTO
# 73795              0               A  TÉCNICO/ACADÉMICO       MIXTO
# 73796              0               A          ACADÉMICO       MIXTO
#
#       cole_jornada cole_mcpio_ubicacion cole_naturaleza cole_sede_principal  \
# ...

# %% [markdown]
# variable cole_calendario

# %%
df['cole_calendario'].unique()
# Out:
# array(['A', 'B'], dtype=object)

# %%
# Convertir la columna 'cole_calendario' en una variable dummy
df['cole_calendario_A'] = df['cole_calendario'].apply(lambda x: 1 if x == 'A' else 0)

# Eliminar la columna original si ya no la necesitas
df = df.drop(columns=['cole_calendario'])

# Mostrar las primeras filas del DataFrame actualizado
df
# Out:
#        cole_bilingue      cole_caracter cole_genero cole_jornada  \
# 0                  0            TÉCNICO       MIXTO       MAÑANA
# 1                  0          ACADÉMICO       MIXTO       MAÑANA
# 2                  0            TÉCNICO       MIXTO       MAÑANA
# 3                  0          ACADÉMICO   MASCULINO     COMPLETA
# 4                  0  TÉCNICO/ACADÉMICO       MIXTO        NOCHE
# ...              ...                ...         ...          ...
# 73792              0  TÉCNICO/ACADÉMICO       MIXTO       MAÑANA
# 73793              0          ACADÉMICO       MIXTO       MAÑANA
# 73794              0          ACADÉMICO       MIXTO       MAÑANA
# 73795              0  TÉCNICO/ACADÉMICO       MIXTO        TARDE
# 73796              0          ACADÉMICO       MIXTO       MAÑANA
#
#       cole_mcpio_ubicacion cole_naturaleza cole_sede_principal  \
# 0              SANTA MARTA         OFICIAL                   S
# ...

# %% [markdown]
# variable cole_caracter

# %%
df['cole_caracter'].unique()
# Out:
# array(['TÉCNICO', 'ACADÉMICO', 'TÉCNICO/ACADÉMICO', 'NO APLICA'],
#       dtype=object)

# %%
# Convertir la variable 'cole_caracter' en variables dummy
df = pd.get_dummies(df, columns=['cole_caracter'], drop_first=True)

# Mostrar las primeras filas del DataFrame actualizado
df
# Out:
#        cole_bilingue cole_genero cole_jornada cole_mcpio_ubicacion  \
# 0                  0       MIXTO       MAÑANA          SANTA MARTA
# 1                  0       MIXTO       MAÑANA             EL PIÑON
# 2                  0       MIXTO       MAÑANA              CIENAGA
# 3                  0   MASCULINO     COMPLETA          SANTA MARTA
# 4                  0       MIXTO        NOCHE          SANTA MARTA
# ...              ...         ...          ...                  ...
# 73792              0       MIXTO       MAÑANA          SANTA MARTA
# 73793              0       MIXTO       MAÑANA              CIÉNAGA
# 73794              0       MIXTO       MAÑANA          SANTA MARTA
# 73795              0       MIXTO        TARDE          SANTA MARTA
# 73796              0       MIXTO       MAÑANA          SANTA MARTA
#
#       cole_naturaleza cole_sede_principal estu_estadoinvestigacion  \
# 0             OFICIAL                   S                 PUBLICAR
# ...

# %%
# Convertir todas las columnas con valores True/False a 0 y 1
columnas_a_convertir = ['cole_caracter_NO APLICA', 'cole_caracter_TÉCNICO', 'cole_caracter_TÉCNICO/ACADÉMICO']
df[columnas_a_convertir] = df[columnas_a_convertir].astype(int)

# Mostrar las primeras filas del DataFrame actualizado
df
# Out:
#        cole_bilingue cole_genero cole_jornada cole_mcpio_ubicacion  \
# 0                  0       MIXTO       MAÑANA          SANTA MARTA
# 1                  0       MIXTO       MAÑANA             EL PIÑON
# 2                  0       MIXTO       MAÑANA              CIENAGA
# 3                  0   MASCULINO     COMPLETA          SANTA MARTA
# 4                  0       MIXTO        NOCHE          SANTA MARTA
# ...              ...         ...          ...                  ...
# 73792              0       MIXTO       MAÑANA          SANTA MARTA
# 73793              0       MIXTO       MAÑANA              CIÉNAGA
# 73794              0       MIXTO       MAÑANA          SANTA MARTA
# 73795              0       MIXTO        TARDE          SANTA MARTA
# 73796              0       MIXTO       MAÑANA          SANTA MARTA
#
#       cole_naturaleza cole_sede_principal estu_estadoinvestigacion  \
# 0             OFICIAL                   S                 PUBLICAR
# ...

# %% [markdown]
# variable cole_genero

# %%
df['cole_genero'].unique()
# Out:
# array(['MIXTO', 'MASCULINO', 'FEMENINO'], dtype=object)

# %%
# Convertir la variable 'cole_genero' en variables dummy
df = pd.get_dummies(df, columns=['cole_genero'], drop_first=True)

# Mostrar las primeras filas del DataFrame actualizado
df
# Out:
#        cole_bilingue cole_jornada cole_mcpio_ubicacion cole_naturaleza  \
# 0                  0       MAÑANA          SANTA MARTA         OFICIAL
# 1                  0       MAÑANA             EL PIÑON         OFICIAL
# 2                  0       MAÑANA              CIENAGA         OFICIAL
# 3                  0     COMPLETA          SANTA MARTA      NO OFICIAL
# 4                  0        NOCHE          SANTA MARTA         OFICIAL
# ...              ...          ...                  ...             ...
# 73792              0       MAÑANA          SANTA MARTA         OFICIAL
# 73793              0       MAÑANA              CIÉNAGA      NO OFICIAL
# 73794              0       MAÑANA          SANTA MARTA         OFICIAL
# 73795              0        TARDE          SANTA MARTA         OFICIAL
# 73796              0       MAÑANA          SANTA MARTA         OFICIAL
#
#       cole_sede_principal estu_estadoinvestigacion estu_estudiante  \
# ...

# %%
# Convertir columnas con valores True/False a 0 y 1
columnas_a_convertir = ['cole_genero_MASCULINO', 'cole_genero_MIXTO']
df[columnas_a_convertir] = df[columnas_a_convertir].astype(int)

# Mostrar las primeras filas del DataFrame actualizado
df
# Out:
#        cole_bilingue cole_jornada cole_mcpio_ubicacion cole_naturaleza  \
# 0                  0       MAÑANA          SANTA MARTA         OFICIAL
# 1                  0       MAÑANA             EL PIÑON         OFICIAL
# 2                  0       MAÑANA              CIENAGA         OFICIAL
# 3                  0     COMPLETA          SANTA MARTA      NO OFICIAL
# 4                  0        NOCHE          SANTA MARTA         OFICIAL
# ...              ...          ...                  ...             ...
# 73792              0       MAÑANA          SANTA MARTA         OFICIAL
# 73793              0       MAÑANA              CIÉNAGA      NO OFICIAL
# 73794              0       MAÑANA          SANTA MARTA         OFICIAL
# 73795              0        TARDE          SANTA MARTA         OFICIAL
# 73796              0       MAÑANA          SANTA MARTA         OFICIAL
#
#       cole_sede_principal estu_estadoinvestigacion estu_estudiante  \
# ...

# %% [markdown]
# variable cole_jornada

# %%
df['cole_jornada'].unique()
# Out:
# array(['MAÑANA', 'COMPLETA', 'NOCHE', 'TARDE', 'UNICA', 'SABATINA'],
#       dtype=object)

# %%
# Convertir la columna 'cole_jornada' en variables dummy
df = pd.get_dummies(df, columns=['cole_jornada'], drop_first=True)

# Mostrar las primeras filas del DataFrame actualizado
df
# Out:
#        cole_bilingue cole_mcpio_ubicacion cole_naturaleza cole_sede_principal  \
# 0                  0          SANTA MARTA         OFICIAL                   S
# 1                  0             EL PIÑON         OFICIAL                   S
# 2                  0              CIENAGA         OFICIAL                   S
# 3                  0          SANTA MARTA      NO OFICIAL                   S
# 4                  0          SANTA MARTA         OFICIAL                   S
# ...              ...                  ...             ...                 ...
# 73792              0          SANTA MARTA         OFICIAL                   S
# 73793              0              CIÉNAGA      NO OFICIAL                   S
# 73794              0          SANTA MARTA         OFICIAL                   S
# 73795              0          SANTA MARTA         OFICIAL                   N
# 73796              0          SANTA MARTA         OFICIAL                   S
#
# ...

# %%
# Seleccionar las columnas que deseas convertir a binarias
columnas_a_convertir = [
    'cole_jornada_MAÑANA',
    'cole_jornada_NOCHE',
    'cole_jornada_SABATINA',
    'cole_jornada_TARDE',
    'cole_jornada_UNICA'
]

# Convertir las columnas de True/False a 0/1
df[columnas_a_convertir] = df[columnas_a_convertir].astype(int)

# Mostrar las primeras filas del DataFrame actualizado
df
# Out:
#        cole_bilingue cole_mcpio_ubicacion cole_naturaleza cole_sede_principal  \
# 0                  0          SANTA MARTA         OFICIAL                   S
# 1                  0             EL PIÑON         OFICIAL                   S
# 2                  0              CIENAGA         OFICIAL                   S
# 3                  0          SANTA MARTA      NO OFICIAL                   S
# 4                  0          SANTA MARTA         OFICIAL                   S
# ...              ...                  ...             ...                 ...
# 73792              0          SANTA MARTA         OFICIAL                   S
# 73793              0              CIÉNAGA      NO OFICIAL                   S
# 73794              0          SANTA MARTA         OFICIAL                   S
# 73795              0          SANTA MARTA         OFICIAL                   N
# 73796              0          SANTA MARTA         OFICIAL                   S
#
# ...

# %% [markdown]
# variable cole_mcipio_ubicacion

# %%
df['cole_mcpio_ubicacion'].unique()
# Out:
# array(['SANTA MARTA', 'EL PIÑON', 'CIENAGA', 'EL BANCO', 'TENERIFE',
#        'CONCORDIA', 'SANTA ANA', 'PIVIJAY', 'PEDRAZA', 'FUNDACION',
#        'ZONA BANANERA', 'SITIONUEVO', 'GUAMAL', 'PLATO', 'ALGARROBO',
#        'FUNDACIÓN', 'PUEBLOVIEJO', 'CIÉNAGA', 'ARACATACA', 'EL RETÉN',
#        'SAN SEBASTIÁN DE BUENAVISTA', 'EL RETEN', 'EL PIÑÓN',
#        'ARIGUANI (EL DIFICIL)', 'CHIVOLO', 'SALAMINA',
#        'PIJIÑO DEL CARMEN', 'ZAPAYAN', 'NUEVA GRANADA',
#        'SANTA BARBARA DE PINTO', 'REMOLINO', 'CERRO SAN ANTONIO',
#        'SABANAS DE SAN ÁNGEL', 'SABANAS DE SAN ANGEL', 'ARIGUANÍ',
#        'SAN ZENON', 'SANTA BÁRBARA DE PINTO',
#        'SAN SEBASTIAN DE BUENAVISTA', 'CERRO DE SAN ANTONIO', 'ZAPAYÁN',
#        'SAN ZENÓN'], dtype=object)

# %% [markdown]
# variable cole_naturaleza

# %%
df['cole_naturaleza'].unique()
# Out:
# array(['OFICIAL', 'NO OFICIAL'], dtype=object)

# %%
# Renombrar la columna
df.rename(columns={'cole_naturaleza': 'cole_naturaleza_oficial'}, inplace=True)

# Convertir a variable binaria
df['cole_naturaleza_oficial'] = df['cole_naturaleza_oficial'].apply(lambda x: 1 if x == 'OFICIAL' else 0)

# Mostrar las primeras filas del DataFrame actualizado
df
# Out:
#        cole_bilingue cole_mcpio_ubicacion  cole_naturaleza_oficial  \
# 0                  0          SANTA MARTA                        1
# 1                  0             EL PIÑON                        1
# 2                  0              CIENAGA                        1
# 3                  0          SANTA MARTA                        0
# 4                  0          SANTA MARTA                        1
# ...              ...                  ...                      ...
# 73792              0          SANTA MARTA                        1
# 73793              0              CIÉNAGA                        0
# 73794              0          SANTA MARTA                        1
# 73795              0          SANTA MARTA                        1
# 73796              0          SANTA MARTA                        1
#
#       cole_sede_principal estu_estadoinvestigacion estu_estudiante  \
# 0                       S                 PUBLICAR      ESTUDIANTE
# ...

# %% [markdown]
# variable cole_sede_principal

# %%
df['cole_sede_principal'].unique()
# Out:
# array(['S', 'N'], dtype=object)

# %%
# Convertir a variable binaria
df['cole_sede_principal'] = df['cole_sede_principal'].apply(lambda x: 1 if x == 'S' else 0)

# Mostrar las primeras filas del DataFrame actualizado
df
# Out:
#        cole_bilingue cole_mcpio_ubicacion  cole_naturaleza_oficial  \
# 0                  0          SANTA MARTA                        1
# 1                  0             EL PIÑON                        1
# 2                  0              CIENAGA                        1
# 3                  0          SANTA MARTA                        0
# 4                  0          SANTA MARTA                        1
# ...              ...                  ...                      ...
# 73792              0          SANTA MARTA                        1
# 73793              0              CIÉNAGA                        0
# 73794              0          SANTA MARTA                        1
# 73795              0          SANTA MARTA                        1
# 73796              0          SANTA MARTA                        1
#
#        cole_sede_principal estu_estadoinvestigacion estu_estudiante  \
# 0                        1                 PUBLICAR      ESTUDIANTE
# ...

# %% [markdown]
# variable estu_estadoinvestigacion

# %%
df['estu_estadoinvestigacion'].unique()
# Out:
# array(['PUBLICAR', 'VALIDEZ OFICINA JURÍDICA',
#        'NO SE COMPROBO IDENTIDAD DEL EXAMINADO',
#        'PRESENTE CON LECTURA TARDIA'], dtype=object)

# %% [markdown]
# variable estu_estudiante

# %%
df["estu_estudiante"].value_counts()
# Out:
# estu_estudiante
# ESTUDIANTE    73797
# Name: count, dtype: int64

# %% [markdown]
# al ver que la variable anterior no explica nada se procede a borrar

# %%
# Eliminar la columna 'estu_estudiente'
df = df.drop(columns=['estu_estudiante'])

# Mostrar las primeras filas del DataFrame actualizado
df
# Out:
#        cole_bilingue cole_mcpio_ubicacion  cole_naturaleza_oficial  \
# 0                  0          SANTA MARTA                        1
# 1                  0             EL PIÑON                        1
# 2                  0              CIENAGA                        1
# 3                  0          SANTA MARTA                        0
# 4                  0          SANTA MARTA                        1
# ...              ...                  ...                      ...
# 73792              0          SANTA MARTA                        1
# 73793              0              CIÉNAGA                        0
# 73794              0          SANTA MARTA                        1
# 73795              0          SANTA MARTA                        1
# 73796              0          SANTA MARTA                        1
#
#        cole_sede_principal estu_estadoinvestigacion estu_genero  \
# 0                        1                 PUBLICAR           M
# ...

# %% [markdown]
# variable estu_genero

# %%
df["estu_genero"].value_counts()
# Out:
# estu_genero
# F    40333
# M    33464
# Name: count, dtype: int64

# %%
# Crear una variable dummy para 'estu_genero'
df['estu_genero_masculino'] = df['estu_genero'].apply(lambda x: 1 if x == 'M' else 0)

# Eliminar la columna 'estu_genero'
df = df.drop(columns=['estu_genero'])
# Mostrar las primeras filas del DataFrame actualizado
df
# Out:
#        cole_bilingue cole_mcpio_ubicacion  cole_naturaleza_oficial  \
# 0                  0          SANTA MARTA                        1
# 1                  0             EL PIÑON                        1
# 2                  0              CIENAGA                        1
# 3                  0          SANTA MARTA                        0
# 4                  0          SANTA MARTA                        1
# ...              ...                  ...                      ...
# 73792              0          SANTA MARTA                        1
# 73793              0              CIÉNAGA                        0
# 73794              0          SANTA MARTA                        1
# 73795              0          SANTA MARTA                        1
# 73796              0          SANTA MARTA                        1
#
#        cole_sede_principal estu_estadoinvestigacion estu_mcpio_reside  \
# 0                        1                 PUBLICAR       SANTA MARTA
# ...

# %% [markdown]
# se borran las variables estu_mcpio_reside y cole_mcpio_ubicacion ya que no se consideran importqantes para el modelo a realizar

# %%
df['estu_mcpio_reside'].unique()
# Out:
# array(['SANTA MARTA', 'EL PIÑÓN', 'CIÉNAGA', 'EL BANCO', 'TENERIFE',
#        'CONCORDIA', 'SANTA ANA', 'PIVIJAY', 'PEDRAZA', 'FUNDACIÓN',
#        'ZONA BANANERA', 'SITIONUEVO', 'GUAMAL', 'PLATO', 'ALGARROBO',
#        'PUEBLOVIEJO', 'ARACATACA', 'EL RETÉN',
#        'SAN SEBASTIÁN DE BUENAVISTA', 'ARIGUANÍ', 'CHIVOLO', 'SALAMINA',
#        'PIJIÑO DEL CARMEN', 'ZAPAYÁN', 'NUEVA GRANADA',
#        'SANTA BÁRBARA DE PINTO', 'REMOLINO', 'CERRO DE SAN ANTONIO',
#        'SABANAS DE SAN ÁNGEL', 'SAN ZENÓN', 'MOMPÓS', 'MARGARITA',
#        'DIBULLA', 'BARRANQUILLA', 'CAMPO DE LA CRUZ', 'EL PEÑÓN',
#        'EL ROSAL', 'TALAIGUA NUEVO', 'CHIRIGUANÁ', 'PINILLOS',
#        'VALLEDUPAR', 'BOSCONIA', 'SINCELEJO', 'RIOHACHA', 'ZAMBRANO',
#        'BOGOTÁ D.C.', 'SOLEDAD', 'CARTAGENA DE INDIAS', 'MAGANGUÉ',
#        'MAICAO', 'ASTREA', 'BUCARAMANGA'], dtype=object)

# %%
df['cole_mcpio_ubicacion'].unique()
# Out:
# array(['SANTA MARTA', 'EL PIÑON', 'CIENAGA', 'EL BANCO', 'TENERIFE',
#        'CONCORDIA', 'SANTA ANA', 'PIVIJAY', 'PEDRAZA', 'FUNDACION',
#        'ZONA BANANERA', 'SITIONUEVO', 'GUAMAL', 'PLATO', 'ALGARROBO',
#        'FUNDACIÓN', 'PUEBLOVIEJO', 'CIÉNAGA', 'ARACATACA', 'EL RETÉN',
#        'SAN SEBASTIÁN DE BUENAVISTA', 'EL RETEN', 'EL PIÑÓN',
#        'ARIGUANI (EL DIFICIL)', 'CHIVOLO', 'SALAMINA',
#        'PIJIÑO DEL CARMEN', 'ZAPAYAN', 'NUEVA GRANADA',
#        'SANTA BARBARA DE PINTO', 'REMOLINO', 'CERRO SAN ANTONIO',
#        'SABANAS DE SAN ÁNGEL', 'SABANAS DE SAN ANGEL', 'ARIGUANÍ',
#        'SAN ZENON', 'SANTA BÁRBARA DE PINTO',
#        'SAN SEBASTIAN DE BUENAVISTA', 'CERRO DE SAN ANTONIO', 'ZAPAYÁN',
#        'SAN ZENÓN'], dtype=object)

# %%
df
# Out:
#        cole_bilingue cole_mcpio_ubicacion  cole_naturaleza_oficial  \
# 0                  0          SANTA MARTA                        1
# 1                  0             EL PIÑON                        1
# 2                  0              CIENAGA                        1
# 3                  0          SANTA MARTA                        0
# 4                  0          SANTA MARTA                        1
# ...              ...                  ...                      ...
# 73792              0          SANTA MARTA                        1
# 73793              0              CIÉNAGA                        0
# 73794              0          SANTA MARTA                        1
# 73795              0          SANTA MARTA                        1
# 73796              0          SANTA MARTA                        1
#
#        cole_sede_principal estu_estadoinvestigacion estu_mcpio_reside  \
# 0                        1                 PUBLICAR       SANTA MARTA
# ...

# %%
# Eliminar las columnas 'estu_mcpio_reside' y 'cole_mcpio_ubicacion'
df = df.drop(columns=['estu_mcpio_reside', 'cole_mcpio_ubicacion'])

# Mostrar las primeras filas del DataFrame actualizado
df
# Out:
#        cole_bilingue  cole_naturaleza_oficial  cole_sede_principal  \
# 0                  0                        1                    1
# 1                  0                        1                    1
# 2                  0                        1                    1
# 3                  0                        0                    1
# 4                  0                        1                    1
# ...              ...                      ...                  ...
# 73792              0                        1                    1
# 73793              0                        0                    1
# 73794              0                        1                    1
# 73795              0                        1                    0
# 73796              0                        1                    1
#
#       estu_estadoinvestigacion estu_nacionalidad estu_pais_reside  \
# 0                     PUBLICAR          COLOMBIA         COLOMBIA
# ...

# %% [markdown]
# variable estu_estadoinvestigacion se elimina porque esta no se considera si es una variable decisiva en los resultados del examen

# %%
# Eliminar la columna estu_estadoinvestigacion
df = df.drop(columns=['estu_estadoinvestigacion'])

# Mostrar las primeras filas del DataFrame actualizado
df
# Out:
#        cole_bilingue  cole_naturaleza_oficial  cole_sede_principal  \
# 0                  0                        1                    1
# 1                  0                        1                    1
# 2                  0                        1                    1
# 3                  0                        0                    1
# 4                  0                        1                    1
# ...              ...                      ...                  ...
# 73792              0                        1                    1
# 73793              0                        0                    1
# 73794              0                        1                    1
# 73795              0                        1                    0
# 73796              0                        1                    1
#
#       estu_nacionalidad estu_pais_reside estu_privado_libertad  \
# 0              COLOMBIA         COLOMBIA                     N
# ...

# %% [markdown]
# variable estu_nacionalidad y estu_pais_reside

# %%
df['estu_pais_reside'].unique()
# Out:
# array(['COLOMBIA', 'VENEZUELA', 'CUBA', 'ARUBA', 'PANAMÁ', 'ESPAÑA',
#        'ARGENTINA', 'VANUATU', 'ITALIA', 'NORUEGA', 'COSTA RICA'],
#       dtype=object)

# %%
df['estu_nacionalidad'].unique()
# Out:
# array(['COLOMBIA', 'VENEZUELA', 'CUBA', 'ARUBA', 'PANAMÁ', 'ESPAÑA',
#        'ARGENTINA', 'VANUATU', 'ITALIA', 'NORUEGA', 'COSTA RICA'],
#       dtype=object)

# %%
# Crear la nueva variable 'pais_nacionalidad_igual' basada en la comparación
df['pais_nacionalidad_reside'] = df.apply(lambda row: 1 if row['estu_pais_reside'] == row['estu_nacionalidad'] else 0, axis=1)

# Eliminar las columnas estu_nacionalidad y estu_pais_reside
df = df.drop(columns=['estu_nacionalidad', "estu_pais_reside"])

# Mostrar las primeras filas del DataFrame actualizado
df
# Out:
#        cole_bilingue  cole_naturaleza_oficial  cole_sede_principal  \
# 0                  0                        1                    1
# 1                  0                        1                    1
# 2                  0                        1                    1
# 3                  0                        0                    1
# 4                  0                        1                    1
# ...              ...                      ...                  ...
# 73792              0                        1                    1
# 73793              0                        0                    1
# 73794              0                        1                    1
# 73795              0                        1                    0
# 73796              0                        1                    1
#
#       estu_privado_libertad fami_estratovivienda fami_personashogar  \
# 0                         N            Estrato 3             Cuatro
# ...

# %% [markdown]
# variable estu_privado_libertad

# %%
# Convertir la columna 'estu_privado_libertad' en binaria
df['estu_privado_libertad'] = df['estu_privado_libertad'].apply(lambda x: 1 if x == 'S' else 0)

# Mostrar las primeras filas del DataFrame actualizado
df
# Out:
#        cole_bilingue  cole_naturaleza_oficial  cole_sede_principal  \
# 0                  0                        1                    1
# 1                  0                        1                    1
# 2                  0                        1                    1
# 3                  0                        0                    1
# 4                  0                        1                    1
# ...              ...                      ...                  ...
# 73792              0                        1                    1
# 73793              0                        0                    1
# 73794              0                        1                    1
# 73795              0                        1                    0
# 73796              0                        1                    1
#
#        estu_privado_libertad fami_estratovivienda fami_personashogar  \
# 0                          0            Estrato 3             Cuatro
# ...

# %% [markdown]
# variable fami_estratovivienda

# %%
df['fami_estratovivienda'].unique()
# Out:
# array(['Estrato 3', 'Estrato 1', 'Estrato 4', 'Estrato 2', 'Sin Estrato',
#        'Estrato 5', 'Estrato 6'], dtype=object)

# %%
# Convertir la columna 'fami_estratovivienda' en variables dummy
df = pd.get_dummies(df, columns=['fami_estratovivienda'], drop_first=True)

# Mostrar las primeras filas del DataFrame actualizado
df
# Out:
#        cole_bilingue  cole_naturaleza_oficial  cole_sede_principal  \
# 0                  0                        1                    1
# 1                  0                        1                    1
# 2                  0                        1                    1
# 3                  0                        0                    1
# 4                  0                        1                    1
# ...              ...                      ...                  ...
# 73792              0                        1                    1
# 73793              0                        0                    1
# 73794              0                        1                    1
# 73795              0                        1                    0
# 73796              0                        1                    1
#
#        estu_privado_libertad fami_personashogar fami_tieneautomovil  \
# 0                          0             Cuatro                  Si
# ...

# %% [markdown]
# variable fami_personashogar

# %%
df['fami_personashogar'].unique()
# Out:
# array(['Cuatro', 'Cinco', '5 a 6', '3 a 4', 'Siete', 'Nueve', '7 a 8',
#        'Una', 'Seis', '9 o más', 'Tres', 'Diez', 'Dos', '1 a 2',
#        'Doce o más', 'Ocho', 'Once'], dtype=object)

# %%
# Definir el mapeo de valores categóricos a numéricos
mapeo_personas_hogar = {
    'Una': 1,
    'Dos': 2,
    'Tres': 3,
    'Cuatro': 4,
    'Cinco': 5,
    'Seis': 6,
    'Siete': 7,
    'Ocho': 8,
    'Nueve': 9,
    'Diez': 10,
    'Once': 11,
    'Doce o más': 12,
    '1 a 2': 1.5,   # Promedio del rango
    '3 a 4': 3.5,   # Promedio del rango
    '5 a 6': 5.5,   # Promedio del rango
    '7 a 8': 7.5,   # Promedio del rango
    '9 o más': 9.5  # Promedio del rango
}

# Aplicar el mapeo a la columna
df['fami_personashogar'] = df['fami_personashogar'].map(mapeo_personas_hogar)

# Mostrar las primeras filas del DataFrame actualizado
df
# Out:
#        cole_bilingue  cole_naturaleza_oficial  cole_sede_principal  \
# 0                  0                        1                    1
# 1                  0                        1                    1
# 2                  0                        1                    1
# 3                  0                        0                    1
# 4                  0                        1                    1
# ...              ...                      ...                  ...
# 73792              0                        1                    1
# 73793              0                        0                    1
# 73794              0                        1                    1
# 73795              0                        1                    0
# 73796              0                        1                    1
#
#        estu_privado_libertad  fami_personashogar fami_tieneautomovil  \
# 0                          0                 4.0                  Si
# ...

# %% [markdown]
# variable fami_tieneautomovil, fami_tienecomputador y fami_tieneinternet

# %%
# Listar las columnas que deseas convertir
columnas_a_convertir = ['fami_tieneautomovil', 'fami_tienecomputador', 'fami_tieneinternet']

# Convertir los valores 'Sí' a 1 y 'No' a 0
df[columnas_a_convertir] = df[columnas_a_convertir].applymap(lambda x: 1 if x == 'Si' else 0)

# Mostrar las primeras filas del DataFrame actualizado
df
# Out:
# C:\Users\Jeronimo Vargas\AppData\Local\Temp\ipykernel_32984\3207440573.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[columnas_a_convertir] = df[columnas_a_convertir].applymap(lambda x: 1 if x == 'Si' else 0)
#        cole_bilingue  cole_naturaleza_oficial  cole_sede_principal  \
# 0                  0                        1                    1
# 1                  0                        1                    1
# 2                  0                        1                    1
# 3                  0                        0                    1
# 4                  0                        1                    1
# ...              ...                      ...                  ...
# 73792              0                        1                    1
# 73793              0                        0                    1
# 73794              0                        1                    1
# ...

# %% [markdown]
# variable desemp_ingles

# %%
df['desemp_ingles'].unique()
# Out:
# array(['A1', 'A-', 'B1', 'A2', 'B+'], dtype=object)

# %%
# Convertir la columna 'desemp_ingles' en variables dummy
df = pd.get_dummies(df, columns=['desemp_ingles'], drop_first=False)

# Mostrar las primeras filas del DataFrame actualizado
df
# Out:
#        cole_bilingue  cole_naturaleza_oficial  cole_sede_principal  \
# 0                  0                        1                    1
# 1                  0                        1                    1
# 2                  0                        1                    1
# 3                  0                        0                    1
# 4                  0                        1                    1
# ...              ...                      ...                  ...
# 73792              0                        1                    1
# 73793              0                        0                    1
# 73794              0                        1                    1
# 73795              0                        1                    0
# 73796              0                        1                    1
#
#        estu_privado_libertad  fami_personashogar  fami_tieneautomovil  \
# 0                          0                 4.0                    1
# ...

# %%
# Seleccionar las columnas que deseas convertir
columnas_a_convertir = [
    'fami_estratovivienda_Estrato 3',
    'fami_estratovivienda_Estrato 4',
    'fami_estratovivienda_Estrato 5',
    'fami_estratovivienda_Estrato 6',
    'fami_estratovivienda_Sin Estrato',
    "fami_estratovivienda_Estrato 2",
    "desemp_ingles_A-",
    "desemp_ingles_A1",
    "desemp_ingles_A2",
    "desemp_ingles_B+",
    "desemp_ingles_B1"

]

# Convertir los valores de True/False a 1/0
df[columnas_a_convertir] = df[columnas_a_convertir].astype(int)

# Mostrar las primeras filas del DataFrame actualizado
df
# Out:
#        cole_bilingue  cole_naturaleza_oficial  cole_sede_principal  \
# 0                  0                        1                    1
# 1                  0                        1                    1
# 2                  0                        1                    1
# 3                  0                        0                    1
# 4                  0                        1                    1
# ...              ...                      ...                  ...
# 73792              0                        1                    1
# 73793              0                        0                    1
# 73794              0                        1                    1
# 73795              0                        1                    0
# 73796              0                        1                    1
#
#        estu_privado_libertad  fami_personashogar  fami_tieneautomovil  \
# 0                          0                 4.0                    1
# ...

# %% [markdown]
# guardar el nuevo DF

# %%
# Opcional: Guardar el DataFrame actualizado en un nuevo archivo CSV
df.to_csv("DF_FINAL.csv", index=False)
df
# Out:
#        cole_bilingue  cole_naturaleza_oficial  cole_sede_principal  \
# 0                  0                        1                    1
# 1                  0                        1                    1
# 2                  0                        1                    1
# 3                  0                        0                    1
# 4                  0                        1                    1
# ...              ...                      ...                  ...
# 73792              0                        1                    1
# 73793              0                        0                    1
# 73794              0                        1                    1
# 73795              0                        1                    0
# 73796              0                        1                    1
#
#        estu_privado_libertad  fami_personashogar  fami_tieneautomovil  \
# 0                          0                 4.0                    1
# ...
